# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Deepika\data analysis\archive\shopping_trends.csv")

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3900, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Category"].value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
data["Age"].plot(kind="hist")
plt.title("HISTOGRAM OF AGE")
plt.show()

# %%
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
data["Gender"].value_counts().plot(kind="bar")
plt.title("Bar graph of gender")
# Out:
# Text(0.5, 1.0, 'Bar graph of gender')

# %%
data["Age"].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 50    83
# 54    83
# 27    83
# 62    83
# 32    82
# 19    81
# 58    81
# 42    80
# 43    79
# 28    79
# 31    79
# 37    77
# 46    76
# 29    76
# 68    75
# 59    75
# 63    75
# 56    74
# 36    74
# 55    73
# 52    73
# 64    73
# 35    72
# 51    72
# 65    72
# 40    72
# 45    72
# 47    71
# 66    71
# 30    71
# 23    71
# 38    70
# 53    70
# 18    69
# 21    69
# 26    69
# 34    68
# 48    68
# 24    68
# 39    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
data["Season"].value_counts()
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: count, dtype: int64

# %%
data["Season"].value_counts().plot(kind="bar")
plt.title("bar graph of seasons")
plt.show()

# %%
data.groupby("Category")["Purchase Amount (USD)"].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
data.groupby("Category")["Purchase Amount (USD)"].mean().plot(kind="bar")
plt.title("Average of category")
plt.show()

# %%
data.groupby("Category")["Review Rating"].mean()
# Out:
# Category
# Accessories    3.768629
# Clothing       3.723143
# Footwear       3.790651
# Outerwear      3.746914
# Name: Review Rating, dtype: float64

# %%
data.groupby("Category")["Review Rating"].mean().plot(kind="bar")
plt.title("bar graph of review and rating by category")
plt.show()

# %%
data.groupby("Category")["Review Rating"].mean().sort_values(ascending=False).head(2)
# Out:
# Category
# Footwear       3.790651
# Accessories    3.768629
# Name: Review Rating, dtype: float64

# %%
data.boxplot(column="Purchase Amount (USD)")
plt.title("Boxplot of Purchase Amount")
plt.show()

# %%
data.boxplot(column="Age")
plt.title("Box plot of Age")
plt.show()

# %%
pd.pivot_table(data, values="Purchase Amount (USD)", 
               index="Category", 
               columns="Gender", 
               aggfunc="mean")
# Out:
# Gender          Female       Male
# Category
# Accessories  60.762755  59.411557
# Clothing     60.496403  59.803556
# Footwear     59.472362  60.645000
# Outerwear    58.425743  56.605381

# %%
pd.pivot_table(data,values="Purchase Amount (USD)",index="Location",columns="Item Purchased", aggfunc="mean")
# Out:
# Item Purchased   Backpack       Belt     Blouse      Boots       Coat  \
# Location
# Alabama         74.000000  26.500000  52.000000  73.666667  54.500000
# Alaska          74.600000  76.750000  67.500000  56.000000  45.500000
# Arizona         48.600000  84.500000  61.000000        NaN  65.333333
# Arkansas        90.000000  55.000000  66.000000  50.000000  54.250000
# California      57.400000  61.666667  39.500000  62.500000  55.000000
# Colorado        57.000000  68.500000  55.000000        NaN  46.000000
# Connecticut     60.000000  47.666667  67.400000  64.250000  44.500000
# Delaware        33.000000  41.500000  42.200000  44.500000  57.500000
# Florida         59.000000  94.000000  31.000000  51.500000  51.166667
# Georgia         44.750000  62.000000  64.857143  85.000000  93.000000
# Hawaii          96.000000  44.000000  50.600000  74.000000  69.666667
# Idaho           53.250000  61.000000  65.000000  60.333333  65.250000
# ...

# %%
import seaborn as sns

sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Dataset has 3900 rows and 19 columns
#
# No missing values or duplicates
#
# More male customers than female
#
# All seasons have equal sales
#
# Average purchase amount is ~$60 across all categories
#
# No outliers in Age or Purchase Amount
#
# Females spend slightly more on Accessories, Males on Footwea
